# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("E:/B-Tech/AI_ML/ASSIGNMENT/pbl_dataset.csv")
df.head(50)
# Out:
#     S NO.  Age  Gender   Income     Employment  LoanAmount  LoanTerm  \
# 0       1   25    Male   300000       Salaried      100000        24
# 1       2   40  Female   800000  Self-employed      300000        36
# 2       3   35    Male   500000       Salaried      200000        48
# 3       4   29  Female   450000       Salaried      150000        36
# 4       5   50    Male   900000       Business      400000        60
# 5       6   32  Female   600000       Salaried      250000        48
# 6       7   28    Male   350000       Salaried      120000        24
# 7       8   45  Female  1000000       Business      500000        60
# 8       9   38    Male   750000  Self-employed      280000        36
# 9      10   27  Female   320000       Salaried      100000        24
# 10     11   41    Male   850000       Business      350000        48
# 11     12   36  Female   620000       Salaried      240000        36
# 12     13   30    Male   400000       Salaried      150000        36
# ...

# %%
df.tail(50)
# Out:
#     S NO.  Age  Gender   Income     Employment  LoanAmount  LoanTerm  \
# 50     51   26    Male   290000       Salaried       90000        24
# 51     52   40  Female   800000       Business      350000        48
# 52     53   35    Male   520000       Salaried      200000        36
# 53     54   44  Female   870000       Business      420000        60
# 54     55   33    Male   570000  Self-employed      210000        48
# 55     56   28  Female   340000       Salaried      110000        24
# 56     57   51    Male  1050000       Business      500000        60
# 57     58   38  Female   710000       Salaried      260000        36
# 58     59   30    Male   420000       Salaried      150000        36
# 59     60   46  Female   900000       Business      430000        60
# 60     61   34    Male   560000  Self-employed      220000        48
# 61     62   27  Female   310000       Salaried      100000        24
# 62     63   42    Male   820000       Business      350000        48
# ...

# %%
df.shape
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S NO.         100 non-null    int64
#  1   Age           100 non-null    int64
#  2   Gender        100 non-null    str
#  3   Income        100 non-null    int64
#  4   Employment    100 non-null    str
#  5   LoanAmount    100 non-null    int64
#  6   LoanTerm      100 non-null    int64
#  7   InterestRate  100 non-null    float64
#  8   CreditScore   100 non-null    int64
#  9   DTI           100 non-null    float64
#  10  PastDefaults  100 non-null    int64
#  11  NumLoans      100 non-null    int64
#  12  Savings       100 non-null    int64
#  13  EMI           100 non-null    int64
#  14  Default       100 non-null    int64
#  15  Unnamed: 15   0 non-null      float64
# dtypes: float64(3), int64(11), str(2)
# memory usage: 12.6 KB
# ...

# %%
df['Gender'] = df['Gender'].str.capitalize()
print(df)
# Out:
#     S NO.  Age  Gender  Income     Employment  LoanAmount  LoanTerm  \
# 0       1   25    Male  300000       Salaried      100000        24
# 1       2   40  Female  800000  Self-employed      300000        36
# 2       3   35    Male  500000       Salaried      200000        48
# 3       4   29  Female  450000       Salaried      150000        36
# 4       5   50    Male  900000       Business      400000        60
# ..    ...  ...     ...     ...            ...         ...       ...
# 95     96   49  Female  970000       Business      460000        60
# 96     97   33    Male  570000  Self-employed      210000        48
# 97     98   28  Female  350000       Salaried      120000        24
# 98     99   50    Male  950000       Business      450000        60
# 99    100   34  Female  620000       Salaried      230000        36
#
#     InterestRate  CreditScore   DTI  PastDefaults  NumLoans  Savings    EMI  \
# ...

# %%
print("Null values:")
print(df.isnull().sum())
# Out:
# Null values:
# S NO.             0
# Age               0
# Gender            0
# Income            0
# Employment        0
# LoanAmount        0
# LoanTerm          0
# InterestRate      0
# CreditScore       0
# DTI               0
# PastDefaults      0
# NumLoans          0
# Savings           0
# EMI               0
# Default           0
# Unnamed: 15     100
# dtype: int64

# %%
print(df.nunique())
# Out:
# S NO.           100
# Age              29
# Gender            2
# Income           52
# Employment        3
# LoanAmount       28
# LoanTerm          4
# InterestRate     45
# CreditScore      28
# DTI              34
# PastDefaults      4
# NumLoans          5
# Savings          33
# EMI              36
# Default           2
# Unnamed: 15       0
# dtype: int64

# %%
df.hist(figsize=(12,10))
plt.show()

# %%
print("LINE GRAPH")
plt.plot(df['Age'], df['Income'])
plt.title("Age vs Income")
plt.show()

plt.plot(df['Age'], df['LoanAmount'])
plt.title("Age vs Loan Amount")
plt.show()

plt.plot(df['Income'], df['LoanAmount'])
plt.title("Income vs Loan Amount")
plt.show()
# Out:
# LINE GRAPH

# %%
sns.countplot(x='Gender', data=df)
plt.show()
sns.countplot(x='Employment', data=df)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title("BOXPLOT")
sns.boxplot(data=df[['Income','LoanAmount','Savings']])
plt.show()

# %%
Q1 = df['Age'].quantile(0.25)

Q3 = df['Age'].quantile(0.75)

IQR = Q3 - Q1

df = df[(df['Age'] >= Q1 - 1.5*IQR) & (df['Age'] <= Q3 + 1.5*IQR)]

df
# Out:
#     S NO.  Age  Gender  Income     Employment  LoanAmount  LoanTerm  \
# 0       1   25    Male  300000       Salaried      100000        24
# 1       2   40  Female  800000  Self-employed      300000        36
# 2       3   35    Male  500000       Salaried      200000        48
# 3       4   29  Female  450000       Salaried      150000        36
# 4       5   50    Male  900000       Business      400000        60
# ..    ...  ...     ...     ...            ...         ...       ...
# 95     96   49  Female  970000       Business      460000        60
# 96     97   33    Male  570000  Self-employed      210000        48
# 97     98   28  Female  350000       Salaried      120000        24
# 98     99   50    Male  950000       Business      450000        60
# 99    100   34  Female  620000       Salaried      230000        36
#
#     InterestRate  CreditScore   DTI  PastDefaults  NumLoans  Savings    EMI  \
# ...

# %%
plt.scatter(df.index, df['Age'])
plt.title("Outliers")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
from scipy import stats
z_scores = np.abs(stats.zscore(df['Income']))
df_clean = df[z_scores < 3]
print("Original Shape:", df.shape)
print("After Removing Outliers:", df_clean.shape)
# Out:
# Original Shape: (100, 16)
# After Removing Outliers: (100, 16)

# %%
print("Mean:\n", df[['Income','LoanAmount','Savings']].mean())
print("\nMedian:\n", df[['Income','LoanAmount','Savings']].median())
print("\nMax:\n", df[['Income','LoanAmount','Savings']].max())
print("\nMin:\n", df[['Income','LoanAmount','Savings']].min())
print("\nStd Dev:\n", df[['Income','LoanAmount','Savings']].std())
# Out:
# Mean:
#  Income        661700.0
# LoanAmount    272500.0
# Savings       126830.0
# dtype: float64
#
# Median:
#  Income        615000.0
# LoanAmount    240000.0
# Savings        92500.0
# dtype: float64
#
# Max:
#  Income        1200000
# LoanAmount     520000
# Savings        310000
# dtype: int64
#
# Min:
#  Income        290000
# LoanAmount     90000
# Savings        35000
# dtype: int64
#
# Std Dev:
#  Income        238856.937022
# LoanAmount    128309.718410
# Savings        74866.622818
# dtype: float64

# %%
df['Gender'] = df['Gender'].replace({
    'M': 'Male',
    'F': 'Female',
    'male': 'Male',
    'female': 'Female'
})
df['Gender']
# Out:
# 0       Male
# 1     Female
# 2       Male
# 3     Female
# 4       Male
#        ...
# 95    Female
# 96      Male
# 97    Female
# 98      Male
# 99    Female
# Name: Gender, Length: 100, dtype: str

# %%
print(df.shape)
print(df.head())
# Out:
# (100, 16)
#    S NO.  Age  Gender  Income     Employment  LoanAmount  LoanTerm  \
# 0      1   25    Male  300000       Salaried      100000        24
# 1      2   40  Female  800000  Self-employed      300000        36
# 2      3   35    Male  500000       Salaried      200000        48
# 3      4   29  Female  450000       Salaried      150000        36
# 4      5   50    Male  900000       Business      400000        60
#
#    InterestRate  CreditScore   DTI  PastDefaults  NumLoans  Savings    EMI  \
# 0          10.5          720  0.25             0         1    50000   4600
# 1          12.2          680  0.35             1         2   150000  10000
# 2          11.0          590  0.45             2         3    80000   6000
# 3           9.5          710  0.28             0         1    60000   4800
# 4          13.5          550  0.50             3         4   200000  12000
#
#    Default  Unnamed: 15
# 0        0          NaN
# 1        0          NaN
# ...
